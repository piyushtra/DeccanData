# %%
import pandas as pd
from matplotlib import pyplot
# %matplotlib inline

# %%
data = pd.read_csv('''https://data.telangana.gov.in/sites/default/files/consumption_detail_06_2021_domestic.csv''')

# %%
#consumption_detail_06_2021_domestic data
data
# Out:
#               circle     division subdivision             section  \
# 0      BANJARA HILLS  GREEN LANDS  GREENLANDS            BEGUMPET
# 1      BANJARA HILLS  GREEN LANDS  GREENLANDS            BEGUMPET
# 2      BANJARA HILLS  GREEN LANDS  GREENLANDS            BEGUMPET
# 3      BANJARA HILLS  GREEN LANDS  GREENLANDS            BEGUMPET
# 4      BANJARA HILLS  GREEN LANDS  GREENLANDS            BEGUMPET
# ...              ...          ...         ...                 ...
# 14000        YADADRI   CHOUTUPPAL  CHOUTUPPAL  BHUDAN POCHAMPALLY
# 14001        YADADRI   CHOUTUPPAL  CHOUTUPPAL  BHUDAN POCHAMPALLY
# 14002        YADADRI   CHOUTUPPAL  CHOUTUPPAL  BHUDAN POCHAMPALLY
# 14003        YADADRI   CHOUTUPPAL  CHOUTUPPAL  BHUDAN POCHAMPALLY
# 14004        YADADRI   CHOUTUPPAL  CHOUTUPPAL  BHUDAN POCHAMPALLY
#
#                         area   catdesc  catcode  totservices  billdservices  \
# 0              ALLAMTHOTABAI  DOMESTIC        1         1134         1102.0
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14005 entries, 0 to 14004
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   circle         14005 non-null  object
#  1   division       14005 non-null  object
#  2   subdivision    14005 non-null  object
#  3   section        14005 non-null  object
#  4   area           13943 non-null  object
#  5   catdesc        14005 non-null  object
#  6   catcode        14005 non-null  int64
#  7   totservices    14005 non-null  int64
#  8   billdservices  13041 non-null  float64
#  9   units          14005 non-null  float64
#  10  load           14005 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.2+ MB

# %%
data = data.dropna(subset=["billdservices"]).dropna(subset=["area"])
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 13020 entries, 0 to 14004
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   circle         13020 non-null  object
#  1   division       13020 non-null  object
#  2   subdivision    13020 non-null  object
#  3   section        13020 non-null  object
#  4   area           13020 non-null  object
#  5   catdesc        13020 non-null  object
#  6   catcode        13020 non-null  int64
#  7   totservices    13020 non-null  int64
#  8   billdservices  13020 non-null  float64
#  9   units          13020 non-null  float64
#  10  load           13020 non-null  float64
# dtypes: float64(3), int64(2), object(6)
# memory usage: 1.2+ MB

# %%
pyplot.xticks(rotation=45, ha='right')
pyplot.bar(x ="circle", height="load", data=data)
# Out:
# <BarContainer object of 13020 artists>

# %%
pd.crosstab(data["circle"], data["units"], aggfunc=sum)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[46], line 1
# ----> 1 pd.crosstab(data["circle"], data["units"], aggfunc=sum)
#
# File ~\Documents\MLProjects\tsdata-env\Lib\site-packages\pandas\core\reshape\pivot.py:650, in crosstab(index, columns, values, rownames, colnames, aggfunc, margins, margins_name, dropna, normalize)
#     555 """
#     556 Compute a simple cross tabulation of two (or more) factors.
#     557
#    (...)
#     647 c      0  0  0
#     648 """
#     649 if values is None and aggfunc is not None:
# --> 650     raise ValueError("aggfunc cannot be used without values.")
#     652 if values is not None and aggfunc is None:
#     653     raise ValueError("values cannot be used without an aggfunc.")
#
# ValueError: aggfunc cannot be used without values.
